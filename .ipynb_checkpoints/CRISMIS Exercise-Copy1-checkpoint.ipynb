# %%
import os
import wget
import requests
from bs4 import BeautifulSoup

rootDirectory = os.getcwd()
cwd = os.getcwd()

# %%
def return_parent_urls(root_url):
    url = root_url
    r = requests.get(url)
    urls = list()
    soup = BeautifulSoup(r.content,'html.parser') 
    for link in soup.find_all('a'):
        urls.append(url + link.get('href'))
    return urls[5:]

def generate_url(year, DOY):
    url = 'https://pdsimage2.wr.usgs.gov/archive/mess-e_v_h-mdis-2-edr-rawdata-v1.0/MSGRMDS_1001/DATA/{}_{}/'.format(str(year), str(DOY))
    return url

def fetch_all_img_links_from_url(url):
    
    # create response object and parse with BeautifulSoup
    r = requests.get(url)
    soup = BeautifulSoup(r.content,'html.parser') 

    # find all links on web-page 
    links = soup.findAll('a') 

    # filter the link sending with .IMG 
    IMG_Links = [url + link['href'] for link in links if link['href'].endswith('IMG')]
    return(IMG_Links)

def create_directory_for_img_files(year, DOY):
    path = os.path.join(rootDirectory, '{}_{}'.format(str(year), str(DOY)))
    try:  
        os.mkdir(path)  
    except OSError as error:  
        print(error)
        
    return path
    
def change_directory(path):
    os.chdir(path)
    cwd = path
    
def download_img_files(inDirectory, IMG_Links):
    change_directory(inDirectory)
    
    for link in IMG_Links:
        r = requests.get(link, stream = True)
        file_name = link.split('/')[-1]
        
        #download started
        print("Downloading {}".format(file_name))
        with open(file_name, 'wb') as f:
            for chunk in r.iter_content(chunk_size = 1024*1024):
                if chunk:
                    f.write(chunk)
        print("Downloaded {}".format(file_name))
    print ("All files downloaded!")

# %%
with open("img_urls.txt", "r") as f:
    img_urls = f.read().split('\n')

# %%
print(len(img_urls))

# !pwd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-39511386fc8f> in <module>
# ----> 1 print(len(img_urls))
#       2
#       3 get_ipython().system('pwd')
#
# NameError: name 'img_urls' is not defined

# %%
# !pwd
fileList = list()
os.chdir(rootDirectory)
for root, dirs, files in os.walk("2011_207"):
    for file in files:
        if file.endswith(".IMG"):
             fileList.append(file)
print(fileList[:10])
# Out:
# /Users/harshitjindal/Desktop/GSOC 2020/cern/CRISMIS/Exam/2011_207
# ['EN0220157827M.IMG', 'EW0220137450B.IMG', 'EN0220157831M.IMG', 'EN0220156099M.IMG', 'EN0220157630M.IMG', 'EN0220157763M.IMG', 'EN0220157893M.IMG', 'EW0220159995G.IMG', 'EW0220159429G.IMG', 'EN0220157954M.IMG']

# %%
import re
from PIL import Image
os.chdir("2011_207")
for file in fileList:
    rawData = open(file, 'rb').read()
    size = re.search("(LINES              = \d\d\d\d)|(LINES              = \d\d\d)", str(rawData))
    pixelDepth = re.search("(SAMPLE_BITS        = \d\d)|(SAMPLE_BITS        = \d)", str(rawData))
    size = (str(size)[-6:-2])
    pixelDepth = (str(pixelDepth)[-4:-2])
    print(int(size))
    print(int(pixelDepth))
    imgSize = (int(size), int(size))
    
    
    
    img = Image.frombytes('L', imgSize, rawData)
    img.save(str(file)+'.tiff')
# Out:
# 512
# 8
# 1024
# 16
# 512
# 8
# 1024
# 8
# 512
# 8
# 512
# 8
# 512
# 8
# 1024
# 8
# 1024
# 8
# 512
# 8
# 1024
# 8
# 1024
# 8
# 1024
# 8
# 1024
# 8
# 1024
# 8
# 1024
# 8
# 512
# 8
# 512
# 8
# 1024
# 8
# 1024
# 8
# 512
# 8
# 512
# 8
# 512
# 8
# 512
# 8
# 512
# 8
# 1024
# 8
# 512
# 8
# 1024
# 8
# 512
# 8
# 1024
# 16
# 1024
# 8
# 1024
# 8
# 512
# 8
# 1024
# 8
# 1024
# 8
# 512
# 8
# 512
# 8
# 1024
# 8
# 1024
# 8
# 512
# 8
# 512
# 8
# 1024
# 8
# 512
# 8
# 1024
# 8
# 1024
# 8
# 1024
# 16
# 512
# 8
# 512
# 8
# 512
# 8
# 1024
# 8
# 512
# 8
# 512
# 8
# 1024
# 8
# 512
# 8
# 512
# 8
# 1024
# 8
# 512
# 8
# 1024
# 8
# 512
# 8
# 512
# 8
# 1024
# 8
# 1024
# 8
# 1024
# 8
# 512
# 8
# 1024
# 8
# 1024
# 8
# 512
# 8
# 1024
# 8
# 1024
# 8
# 512
# 8
# 1024
# 8
# 512
# 8
# 1024
# 8
# 512
# 8
# 512
# 8
# 512
# 8
# 1024
# 8
# 512
# 8
# 512
# 8
# 512
# 8
# 512
# 8
# 512
# 8
# 512
# 8
# 512
# 8
# 512
# 8
# 512
# 8
# 1024
# 8
# 1024
# 8
# 512
# 8
# 512
# 8
# 512
# 8
# 1024
# 8
# 512
# 8
# 512
# 8
# 1024
# 8
# 512
# 8
# 1024
# 8
# 1024
# 8
# 1024
# 8
# 1024
# 8
# 512
# 8
# 1024
# 8
# 512
# 8
# 1024
# 8
# 1024
# 8
# 512
# 8
# 512
# 8
# 512
# 8
# 512
# 8
# 1024
# 8
# 1024
# 8
# 1024
# 8
# 512
# 8
# 512
# 8
# 1024
# 8
# 512
# 8
# 1024
# 8
# 1024
# 8
# 1024
# 8
# 512
# 8
# 1024
# 8
# 512
# 8
# 512
# 8
# 512
# 8
# 1024
# 8
# 1024
# 8

# %%
# !pwd
# Out:
# /Users/harshitjindal/Desktop/GSOC 2020/cern/CRISMIS/Exam

# %%
year, DOY = input("Enter Year and DOY: ").split(" ")
url = generate_url(year, DOY)
IMG_Links = fetch_all_img_links_from_url(url)
path = create_directory_for_img_files(year, DOY)
change_directory(path)

download_img_files(inDirectory=path, IMG_Links=IMG_Links)
# Out:
# Enter Year and DOY: 2011 155
# Downloading EN0215633328M.IMG
# Downloaded EN0215633328M.IMG
# Downloading EN0215633332M.IMG
# Downloaded EN0215633332M.IMG
# Downloading EN0215633336M.IMG
# Downloaded EN0215633336M.IMG
# Downloading EN0215633340M.IMG
# Downloading EW0215651178G.IMG
# Downloaded EW0215651178G.IMG
# Downloading EW0215651180J.IMG
# Downloaded EW0215651180J.IMG
# Downloading EW0215651182L.IMG
# Downloaded EW0215651182L.IMG
# Downloading EW0215676413G.IMG
# Downloaded EW0215676413G.IMG
# Downloading EW0215676440G.IMG
# Downloaded EW0215676440G.IMG
# Downloading EW0215676592G.IMG
# Downloaded EW0215676592G.IMG
# Downloading EW0215676616G.IMG
# Downloaded EW0215676616G.IMG
# Downloading EW0215676668G.IMG
# Downloaded EW0215676668G.IMG
# Downloading EW0215676694G.IMG
# Downloaded EW0215676694G.IMG
# Downloading EW0215676720G.IMG
# Downloaded EW0215676720G.IMG
# Downloading EW0215676774G.IMG
# Downloaded EW0215676774G.IMG
# Downloading EW0215677029G.IMG
# Downloaded EW0215677029G.IMG
# Downloading EW0215677068G.IMG
# Downloaded EW0215677068G.IMG
# Downloading EW0215677378F.IMG
# Downloaded EW0215677378F.IMG
# Downloading EW0215677382G.IMG
# Downloaded EW0215677382G.IMG
# Downloading EW0215677386I.IMG
# Downloaded EW0215677386I.IMG
# Downloading EW0215677964G.IMG
# Downloaded EW0215677964G.IMG
# Downloading EW0215683365I.IMG
# Downloaded EW0215683365I.IMG
# Downloading EW0215683369F.IMG
# Downloaded EW0215683369F.IMG
# Downloading EW0215683373C.IMG
# Downloaded EW0215683373C.IMG
# Downloading EW0215683377D.IMG
# Downloaded EW0215683377D.IMG
# Downloading EW0215683381E.IMG
# Downloaded EW0215683381E.IMG
# Downloading EW0215683385G.IMG
# Downloaded EW0215683385G.IMG
# Downloading EW0215683389J.IMG
# Downloaded EW0215683389J.IMG
# Downloading EW0215683393L.IMG
# Downloaded EW0215683393L.IMG
# Downloading EW0215684836I.IMG
# Downloaded EW0215684836I.IMG
# Downloading EW0215684840F.IMG
# Downloaded EW0215684840F.IMG
# Downloading EW0215684844C.IMG
# Downloaded EW0215684844C.IMG
# Downloading EW0215684848D.IMG
# Downloaded EW0215684848D.IMG
# Downloading EW0215684852E.IMG
# Downloaded EW0215684852E.IMG
# Downloading EW0215684856G.IMG
# Downloaded EW0215684856G.IMG
# Downloading EW0215684860J.IMG
# Downloaded EW0215684860J.IMG
# Downloading EW0215684864L.IMG
# Downloaded EW0215684864L.IMG
# All files downloaded!

# %%
import time
img_urls = list()
urls = return_parent_urls("https://pdsimage2.wr.usgs.gov/archive/mess-e_v_h-mdis-2-edr-rawdata-v1.0/MSGRMDS_1001/DATA/")

counter = 0


for url in urls:
    r = requests.get(url)
    soup = BeautifulSoup(r.content,'html.parser') 

    # find all links on web-page 
    links = soup.findAll('a') 

    # filter the link sending with .IMG 
    IMG_Links = [url + link['href'] for link in links if link['href'].endswith('IMG')]
    img_urls.extend(IMG_Links)
    
    counter+=1
    print(counter, end='\t\t')
